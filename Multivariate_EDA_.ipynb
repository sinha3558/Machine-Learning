# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flight = sns.load_dataset("flights")

# %%
flight.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
iris1 = sns.load_dataset("iris")

# %%
iris1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
titnic = sns.load_dataset("titanic")

# %%
titnic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.scatterplot(x = tips["total_bill"],y = tips["tip"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = tips["total_bill"],y = tips["tip"],hue=tips["sex"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = tips["total_bill"],y = tips["tip"],hue=tips["sex"],style=tips['smoker'] )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = tips["total_bill"],y = tips["tip"],hue=tips["sex"],style=tips['smoker'],size= tips["size"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
titnic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.barplot(data=titnic, x="pclass", y="age")
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.barplot(data=titnic, x="pclass", y="fare")
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
sns.barplot(data=titnic, x="pclass", y="fare",hue="sex")
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
sns.barplot(data=titnic, x="pclass", y="age",hue="sex")
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(data = titnic,x="sex",y="age")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(data = titnic,x="sex",y="age",hue="survived")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.distplot(titnic[titnic["survived"]==0]["age"],hist=False)
sns.distplot(titnic[titnic["survived"]==1]["age"],hist=False)
# Out:
# /tmp/ipython-input-3436488348.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titnic[titnic["survived"]==0]["age"],hist=False)
# /tmp/ipython-input-3436488348.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titnic[titnic["survived"]==1]["age"],hist=False)
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.histplot(
    data=titnic[titnic["survived"] == 0],
    x="age",
    kde=True,
    label="Not Survived"
)

sns.histplot(
    data=titnic[titnic["survived"] == 1],
    x="age",
    kde=True,
    label="Survived"
)
plt.legend()

# %%
titnic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titnic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
pd.crosstab(titnic["pclass"],titnic["survived"])
# Out:
# survived    0    1
# pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
pd.crosstab(titnic["pclass"],titnic["survived"]).reset_index()
# Out:
# survived  pclass    0    1
# 0              1   80  136
# 1              2   97   87
# 2              3  372  119

# %%
pd.crosstab(titnic["pclass"],titnic["survived"]).rename(columns={0 : "Not survied",1 : "Survived"}).reset_index()
# Out:
# survived  pclass  Not survied  Survived
# 0              1           80       136
# 1              2           97        87
# 2              3          372       119

# %%
pd.crosstab(titnic["pclass"],titnic["survived"]).rename(columns={0 : "Not survied",1 : "Survived"})
# Out:
# survived  Not survied  Survived
# pclass
# 1                  80       136
# 2                  97        87
# 3                 372       119

# %%
sns.heatmap(pd.crosstab(titnic["pclass"],titnic["survived"]).rename(columns={0 : "Not survied",1 : "Survived"}).reset_index(),annot=True)
# Out:
# <Axes: xlabel='survived'>

# %%
corr = titnic.corr(numeric_only=True)
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
titnic.groupby("pclass")["survived"].mean()
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %%
round(titnic.groupby("pclass")["survived"].mean()*100,2)
# Out:
# pclass
# 1    62.96
# 2    47.28
# 3    24.24
# Name: survived, dtype: float64

# %%
round(titnic.groupby("pclass")["survived"].mean()*100,2).astype(int).astype("str")+"%"
# Out:
# pclass
# 1    62%
# 2    47%
# 3    24%
# Name: survived, dtype: object

# %%
round(titnic.groupby("pclass")["survived"].mean()*100,2).astype(int)
# Out:
# pclass
# 1    62
# 2    47
# 3    24
# Name: survived, dtype: int64

# %%
round(titnic.groupby("pclass")["survived"].mean()*100,2).astype(int).astype("str")
# Out:
# pclass
# 1    62
# 2    47
# 3    24
# Name: survived, dtype: object

# %%
round(titnic.groupby("embark_town")["survived"].mean()*100,2).astype(int).astype("str")+"%"
# Out:
# embark_town
# Cherbourg      55%
# Queenstown     38%
# Southampton    33%
# Name: survived, dtype: object

# %%
titnic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
round(titnic.groupby("sibsp")["survived"].mean()*100,2).astype(int).astype("str")+"%"
# Out:
# sibsp
# 0    34%
# 1    53%
# 2    46%
# 3    25%
# 4    16%
# 5     0%
# 8     0%
# Name: survived, dtype: object

# %%
ct = pd.crosstab(titnic["sibsp"],titnic["survived"]).reset_index()
ct
# Out:
# survived  sibsp    0    1
# 0             0  398  210
# 1             1   97  112
# 2             2   15   13
# 3             3   12    4
# 4             4   15    3
# 5             5    5    0
# 6             8    7    0

# %%
sns.clustermap(ct,cmap="coolwarm", annot=True)

# %%
ct = pd.crosstab(titnic["parch"],titnic["survived"]).reset_index()
ct
# Out:
# survived  parch    0    1
# 0             0  445  233
# 1             1   53   65
# 2             2   40   40
# 3             3    2    3
# 4             4    4    0
# 5             5    4    1
# 6             6    1    0

# %%
sns.clustermap(ct,cmap="coolwarm", annot=True)

# %%
ct2 = pd.crosstab(titnic["parch"],titnic["survived"]).reset_index()
ct2
# Out:
# survived  parch    0    1
# 0             0  445  233
# 1             1   53   65
# 2             2   40   40
# 3             3    2    3
# 4             4    4    0
# 5             5    4    1
# 6             6    1    0

# %%
sns.clustermap(ct2,cmap="coolwarm", annot=True)

# %%
iris1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris1)

# %%
sns.pairplot(iris1,hue="species")

# %%
flight.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flight.groupby("year")["passengers"].sum().sort_values()
# Out:
# year
# 1949    1520
# 1950    1676
# 1951    2042
# 1952    2364
# 1953    2700
# 1954    2867
# 1955    3408
# 1956    3939
# 1957    4421
# 1958    4572
# 1959    5140
# 1960    5714
# Name: passengers, dtype: int64

# %%
flight.groupby("year")["passengers"].sum().sort_values(ascending=False).reset_index()
# Out:
#     year  passengers
# 0   1960        5714
# 1   1959        5140
# 2   1958        4572
# 3   1957        4421
# 4   1956        3939
# 5   1955        3408
# 6   1954        2867
# 7   1953        2700
# 8   1952        2364
# 9   1951        2042
# 10  1950        1676
# 11  1949        1520

# %%
sns.lineplot(flight.groupby("year")["passengers"].sum().sort_values(ascending=False))
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(flight.groupby("year")["passengers"].sum().sort_values(ascending=False), marker="o")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
flight.pivot_table(values="passengers",index="month",columns="year")
# Out:
# /tmp/ipython-input-3253843679.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flight.pivot_table(values="passengers",index="month",columns="year")
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# Dec    118.0  140.0  166.0  194.0  201.0  229.0  278.0  306.0  336.0  337.0
#
# year    1959   1960
# month
# Jan    360.0  417.0
# Feb    342.0  391.0
# Mar    406.0  419.0
# Apr    396.0  461.0
# May    420.0  472.0
# Jun    472.0  535.0
# Jul    548.0  622.0
# Aug    559.0  606.0
# Sep    463.0  508.0
# Oct    407.0  461.0
# Nov    362.0  390.0
# Dec    405.0  432.0

# %%
flight.pivot_table(values="passengers",index="month",columns="year").reset_index()
# Out:
# /tmp/ipython-input-2117532701.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flight.pivot_table(values="passengers",index="month",columns="year").reset_index()
# year month   1949   1950   1951   1952   1953   1954   1955   1956   1957  \
# 0      Jan  112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0
# 1      Feb  118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0
# 2      Mar  132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0
# 3      Apr  129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0
# 4      May  121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0
# 5      Jun  135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0
# 6      Jul  148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0
# 7      Aug  148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0
# 8      Sep  136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0
# 9      Oct  119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0
# 10     Nov  104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0
# 11     Dec  118.0  140.0  166.0  194.0  201.0  229.0  278.0  306.0  336.0
#
# year   1958   1959   1960
# 0     340.0  360.0  417.0
# 1     318.0  342.0  391.0
# 2     362.0  406.0  419.0
# 3     348.0  396.0  461.0
# 4     363.0  420.0  472.0
# 5     435.0  472.0  535.0
# 6     491.0  548.0  622.0
# 7     505.0  559.0  606.0
# 8     404.0  463.0  508.0
# 9     359.0  407.0  461.0
# 10    310.0  362.0  390.0
# 11    337.0  405.0  432.0

# %%
sns.heatmap(flight.pivot_table(values="passengers",index="month",columns="year"))
# Out:
# /tmp/ipython-input-1679599336.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(flight.pivot_table(values="passengers",index="month",columns="year"))
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(flight.pivot_table(values="passengers",index="month",columns="year"))
# Out:
# /tmp/ipython-input-2817533266.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.clustermap(flight.pivot_table(values="passengers",index="month",columns="year"))
